# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51621/2303A51621/blob/main/assignment_kushal_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = ['Kiran','Arun','Vijay','Varun']
age = [25,30,35,40]
height = [145,151,165,173]
weight = [45,55,65,75]


import matplotlib.pyplot as plt


plt.scatter(people,age,label = 'people and age')
plt.xlabel('people')
plt.ylabel('age')
plt.legend(loc = 'lower right')
plt.grid(True,linewidth=1,linestyle='--')
plt.title("Relationn between age and people")
plt.show()
plt.figure(figsize = (12,4))
plt.title("People's weight in kgs ",fontsize=16,fontstyle='italic')
plt.bar(people,weight,width=0.6,color='k',edgecolor='b',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs) ",fontsize=15)
plt.show()
import numpy as np
plt.figure(figsize=(7,5))

plt.hist(weight, color='g',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("weight in kgs", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
